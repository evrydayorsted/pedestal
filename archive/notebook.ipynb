# %%
from Shot import *

# %%
#test pkl download on all shots and make contour plot
a = Shot("allShots", "pkl")
dtype = [('W_ped', float), ('Beta_ped', float), ('elong', float)]
value = np.array([])
for i in range(len(a.W_ped)):
    value =np.append(value, [a.W_ped[i], a.Beta_ped[i], a.elong[i]])
print(value)
a = np.array(value, dtype=dtype)       # create a structured array
a
# np.sort(a, order='height')           
# np.sort(a.elong)
# Out:
# Pkl data loaded
# [0.09459079 0.01053872 1.9561518  ... 1.27320937 2.65773999 1.43160945]
# array([(0.09459079, 0.09459079, 0.09459079),
#        (0.01053872, 0.01053872, 0.01053872),
#        (1.9561518 , 1.9561518 , 1.9561518 ), ...,
#        (1.27320937, 1.27320937, 1.27320937),
#        (2.65773999, 2.65773999, 2.65773999),
#        (1.43160945, 1.43160945, 1.43160945)],
#       dtype=[('W_ped', '<f8'), ('Beta_ped', '<f8'), ('elong', '<f8')])

# %%
# test pkl download on single shot, make a contour plot, plot subdata
b = Shot(48339, "pkl")
b.contourPlot(4)
plt.plot(b.W_ped, b.Beta_ped)
plt.xlabel("W_ped")
plt.ylabel("Beta_ped")
plt.show()
# Out:
# Pkl data loaded

# %%
# test client download and make animation
c = Shot(48339, "client")
c.makeAnimation("te")
# Out:
# Getting data from client for 48339
# Client connection failed.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # test client download and make animation
#       2 c = Shot(48339, "client")
# ----> 3 c.makeAnimation("te")
#
# File ~/Documents/hardDrive/pppl/pedestal/testPedestal.py:790, in Shot.makeAnimation(self, yvalue)
#     788     raise Exception("only run animation on single shot")
#     789 if not self.client:
# --> 790     raise Exception("Must have client data to run animation")
#     791 def createAnimation(yvalue, yparam):
#     792     '''Helper function which creates animation of yparam vs
#     793     radius across time for shot number shotNum. yvalue is
#     794     the string representation of yparam.'''
#
# Exception: Must have client data to run animation

# %%
# test fit
c.fit(presetTimes = [0.173,0.456])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # test fit
# ----> 2 c.fit(presetTimes = [0.173,0.456])
#
# AttributeError: 'Shot' object has no attribute 'fit'

# %%
from Shot import *

a = Shot(47886, "pkl")
# Out:
# pedinf connection failed
# pyuda connection failed
# Pkl data loaded

# %%
plt.plot(a.NBI)

# %%
b = Shot(47888, "pkl")
plt.plot(b.times, b.NBI)
# Out:
# Pkl data loaded

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
shots = [
47885,47886,47888,47889,47890,47891,47893,47894,47918,47955,47958,47959,47961,47962,47963,47964,47979,47980,47985,47989,47990,47991,47996,47997,47998,47999,48000,48002,48003,48004,48005,48006,48008, 48009, 48010, 48012, 48057, 48058, 48060, 48061, 48062, 48064, 48065, 48066, 48068, 48069, 48070, 48072, 48073, 48074, 48079, 48080, 48081, 48082, 48083, 48087, 48088, 48089, 48093, 48094,48103,48104,48107,48108,48109,48110,48111,48112,48113,48114,48115,48116,48117,48118,48119,48120,48121,48122,48123,48124,48125,48126,48127,48129,48130,48131,48132,48133,48134,48135,48136,48137,48151,48155,48157,48158,48159,48160,48164,48168,48172,48173,48174,48175,48176,48177,48178,48180,48181,48183,48186,48187,48188,48189,48193,48194,48196,48198,48200,48219,48221,48223,48233,48235,48251,48252,48255,48256,48257,48
    plt.title(i)
    plt.show()

# %%
a.contourPlot(12, lowSlopeFilter=True,numPix=50,IpMin=0.9, numMin=0, cbarMin=1.9,cbarMax=2.2, countType="elong")

# %%
a.contourPlot(10, lowSlopeFilter=False, IpMin=0.9, numMin=0, posPed=False)

# %%
a.contourPlot(2, lowSlopeFilter=True,numPix=40,IpMin=0.9, numMin=10, cbarMin=1.95,cbarMax=2.1, countType="elong", posPed=False)

# %%
a.contourPlot(3, numMin=0, lowSlopeFilter=False, IpMin=0, posPed=True)

# %%
plt.plot(a.shotByTimeSlice)

# %%
shots = np.array(a.shotByTimeSlice)
times = np.array(a.times)
index = np.where((np.array(a.H_ped_psin_ne/1.0e20))<0)
plt.plot(np.array(a.H_ped_psin_ne))
plt.plot(np.array(a.H_ped_psin_ne)[index])

# %%
from Shot import *
a = Shot("allShots", "pkl")

shots = np.array(a.shotByTimeSlice)
times = np.array(a.times)
IpAdjusted = np.array(a.IpAdjusted)
IpMax = np.array(a.IpMax)
print(a.IpAdjusted)
index = np.where((np.array(a.H_ped_psin_ne)/1.0e20<0.205) &
                 (np.array(a.H_ped_psin_ne)/1.0e20>0.195) &
                 (a.Beta_ped/a.W_ped >0.75) &
                 (np.array(a.elong)> 2.1)&
                 (np.array(a.H_ped_psin_te)/1000.0>0.2) &
                 (np.array(a.IpAdjusted)>0.9*np.array(a.IpMax)))
highElongShotTimes = (shots[index], times[index], np.array(a.elong)[index])
print(highElongShotTimes)

print(len(highElongShotTimes[0]))

print(len(highElongShotTimes[1]))
for i in range(0, 70, 7):
    print("elong", highElongShotTimes[2][i])
    b = Shot(highElongShotTimes[0][i], "both")
    b.fit(plotVsRadius = True, saveFigure=True, showFigure=True, presetTimes = [highElongShotTimes[1][i]], printQuantities=True)

# %%
a.contourPlot(3, countType="elong", cbarMin=1.9, cbarMax=2.1, numMin=10)

# %%
a.contourPlot(2, countType="elong", cbarMin=1.9, cbarMax=2.1, numMin=10)

# %%
a.contourPlot(4, countType="elong", cbarMin=1.9, cbarMax=2.1, numMin=10)

# %%
shot61= Shot(45261, "all")
shot70= Shot(45270, "all")
shot72= Shot(45272, "pkl")

# %%
shots = [shot61, shot70, shot72]

for i in shots:
    i.fit(savefigure=True, showfigure=True, plotvsradius=True, plotvspsin=True, presetTimes[])

# %%
a.contourPlot(5)

# %%
def curve(elong, delta, Beta_ped, elongPower, ), ,m):
    return  m*x

(popt,pcov) = curve_fit(curve, validXQuantity, validYQuantity, p0=(20))
# popt now holds the optimized parameters a in popt[0] and b in popt[1]
# pcov is the covariance matrix, which gives errors and correlations.
# To extract just the errors on the fit parameters as sigmas:
popt = np.round(popt, 3)
perr = np.round(np.sqrt(np.diag(pcov)), 3)
# now perr holds the +- 1sigma error for a and b.
# First plot the data with error bars
#plt.plot(xquantity, yquantity, "o", label="data", color="black")
# There are many ways to plot the line given a and b, but here’s one:
yfit = curve(x_width, *popt) # * passes a list as remaining function parameters

# plots the fit curve
plt.plot(x_width, yfit,label=f"fit - {popt[0]}$\pm${perr[0]} $\delta$", color="black")

#Plots the points that were fitted
plt.plot(validXQuantity, validYQuantity, ".", markersize = 0.5, color="red")
plt.legend()
# savefig("hw1_meaningful_file_name.pdf")

# %%
from Shot import *
allShots = Shot("allShots", "pkl")

# %%
for i in range(10):
    allShots.contourPlot(1, savefigure=False, IpMin=0.1*i)

# %%
# make scatter plot colored by time 

plt.scatter(x=allShots.W_ped, y=allShots.Beta_ped, c=allShots.Ip[np.argmin(np.abs(allShots.IpTime-allShots.times    ))]/np.max(allShots.Ip), cmap="rainbow", s= 0.6, alpha=0.6) 
plt.xlim(1, 3)
plt.xlabel(r"Aspect Ratio")
plt.ylabel(r"$\delta$")
plt.ylim(0,.75)
plt.colorbar(label="Time in shot", orientation="horizontal") 
plt.savefig("allShotsAratioVsDeltaTimeColored.png")
plt.show()

# %%
allShots.times.shape

# %%
# from Shot import *
# listMaxes = []
# IpAdjusted = []
# totalTimes = 0
# for i in range(2000):
#     value = 47885 + i
#     try:
#         a = Shot(value, "pkl")
#         totalTimes +=len(a.times)
#         print(np.max(a.Ip))
#         localIpAdj=[]
#         for k in a.times:
#             localIpAdj += [a.Ip[np.argmin(np.abs(a.IpTime-k))]]
#         for j in range(len(a.times)):
#             listMaxes += [np.max(localIpAdj)]
#         IpAdjusted += localIpAdj
#     except:
#         pass
# print(listMaxes)
# print(len(listMaxes))
# print(IpAdjusted)
# print(len(IpAdjusted))
from Shot import *
shotNums = []
totalTimes = 0
for i in range(2000):
    value = 47885 + i
    try:
        a = Shot(value, "pkl")
        totalTimes +=len(a.times)       
        for j in range(len(a.times)):
            shotNums += [value]
    except:
        pass
print(totalTimes)
print(shotNums)
print(len(shotNums))

# %%
plt.plot(shotNums)

# %%
plt.plot(listMaxes)

# %%
np.ones(10, dtype=float)*2

# %%
filename = 'outputWithPlasmaCurrent/MAST-U_pedestal_allShots.pkl'
infile = open(filename, 'rb')
pkldata = pickle.load(infile)
infile.close()

#read off values
shot = pkldata['Shot']
times = pkldata['Times']
W_ped = pkldata['W_ped']
Beta_ped = pkldata['Beta_ped']
W_ped_psin_te = pkldata['W_ped_psin_te']
W_ped_psin_ne = pkldata['W_ped_psin_ne']
W_ped_psin_pe = pkldata['W_ped_psin_pe']
H_ped_psin_te = pkldata['H_ped_psin_te']
H_ped_psin_ne = pkldata['H_ped_psin_ne']
H_ped_psin_pe = pkldata['H_ped_psin_pe']
W_ped_radius_te = pkldata['W_ped_radius_te']
W_ped_radius_ne = pkldata['W_ped_radius_ne']
W_ped_radius_pe = pkldata['W_ped_radius_pe']
H_ped_radius_te = pkldata['H_ped_radius_te']
H_ped_radius_ne = pkldata['H_ped_radius_ne']
H_ped_radius_pe = pkldata['H_ped_radius_pe']
Aratio = pkldata['Aratio']
elong  = pkldata['elong']
delta = pkldata['delta']
Ip = pkldata['Ip']
IpTime = pkldata['IpTime']
listMaxes = pkldata['IpMax']
IpAdjusted = pkldata['IpTimeAdjusted']
shotNums = pkldata['ShotNum']

print("Pkl data loaded")
pkldata = {'Shot': shot, 'Times': times, 'W_ped': W_ped, 'Beta_ped': Beta_ped,
                    'W_ped_psin_te': W_ped_psin_te,'W_ped_psin_ne': W_ped_psin_ne,'W_ped_psin_pe': W_ped_psin_pe,
                    'H_ped_psin_te': H_ped_psin_te,'H_ped_psin_ne': H_ped_psin_ne,'H_ped_psin_pe': H_ped_psin_pe,
                    'W_ped_radius_te': W_ped_radius_te,'W_ped_radius_ne': W_ped_radius_ne,'W_ped_radius_pe': W_ped_radius_pe,
                    'H_ped_radius_te': H_ped_radius_te,'H_ped_radius_ne': H_ped_radius_ne,'H_ped_radius_pe': H_ped_radius_pe,
                    'Aratio': Aratio, 'elong': elong, 'delta': delta, 'Ip': Ip, 'IpTime': IpTime, "IpMax":listMaxes, "IpTimeAdjusted": IpAdjusted, 'ShotNum': shotNums}
filename = 'outputWithPlasmaCurrent/MAST-U_pedestal_allShots240702.pkl'
outfile = open(filename, 'wb')
pickle.dump(pkldata,outfile)
outfile.close()
# Out:
# Pkl data loaded

# %%
from Shot import *
b = Shot("allShots", "pkl")

# %%
for i in range(10):
    b.contourPlot(1, savefigure=False, IpMin=0.9, LModeFilter=False)

# %%
# make scatter plot colored by time 

plt.scatter(y=b.delta, x=b.elong, c=np.array(b.IpAdjusted)/np.array(b.IpMax), cmap="rainbow", s= 0.6, alpha=0.6) 
# plt.xlim(1,3)
plt.ylabel(r"$\delta$")
plt.xlabel(r"$\kappa$")
# plt.ylim(0,1)
plt.colorbar(label="Fraction of Max Plasma Current", orientation="horizontal") 
plt.savefig("allShotsElongVsDeltaIpColored.png")
plt.show()

# %%
plt.plot(np.array(b.IpAdjusted)/np.array(b.IpMax))
# plt.xlim(0, 1000)

# %%
plt.plot(b.IpMax)
plt.xlim(0, 1000)

# %%
b = Shot("allShots", "pkl")
b.contourPlot(1,IpMin=0.90)

# %%
b.contourPlot(10, IpMin=0, savefigure=False)

# %%
from Shot import *
b = Shot("allShots", "pkl")
b.contourPlot(10, IpMin=0.9, numMin=10, cbarMin=1, cbarMax=3,savefigure=False, LModeFilter=True)

# %%
b.contourPlot(1, savefigure=False)

# %%
from Shot import *
a = Shot("allShots", "pkl")

# %%
a.contourPlot(2, numMin=10, numPix= 40,LModeFilter=True, countType="elong",cbarMin=1.95, cbarMax=2.1)

# %%
print(len(a.zz[:, j]))
for j in range(4,16,4):
    averaged =[]
    errbar = []
    for i in range(2, len(a.zz[:, j])-2):
        averaged += [np.sum(a.zz[i-2:i+3, j])/5]
        errbar += [np.std(a.zz[i-2:i+3, j])]
    print(averaged)
    # plt.plot(a.zz[:, 17])
    plt.errorbar(np.linspace(0, 0.2, len(a.zz[:,j])-4),y=averaged, yerr=errbar, fmt='o', linestyle='-', capsize=4,label="Delta="+str(np.round(j*0.2/len(a.zz[:,j]), 5)))
plt.ylabel(r"Average $\kappa$")
plt.xlabel(r"$T{e, ped}$")
plt.legend()
plt.show()
# for k in range(0,15,1):
    
#     plt.plot(np.linspace(0, 0.2, len(a.zz[:,j])),a.zz[:,j], label="Delta="+str(np.round(j*0.1/15, 2)))
# plt.ylabel(r"Average $\kappa$")
# plt.xlabel(r"$\Delta_{ped, Te}$")
# plt.legend()
# plt.show()

# %%
j = 5
averaged =[]
for i in range(2, len(a.zz[:, j])-2):
    averaged += [np.sum(a.zz[i-2:i+3, j])/5]


# plt.plot(a.zz[:, 17])
plt.plot(averaged, label=j)
plt.legend()

# %%
for i in range(10):
    plt.plot(a.zz[:,int(0.01*i*300)], label=0.01*i)
plt.legend()

# %%
a.contourPlot(0, LModeFilter=True, numMin=10, cbarMin = 1, cbarMax =2)

# %%
a.contourPlot(11, LModeFilter=True, numMin=10, cbarMin=1)

# %%
a.contourPlot(8, numPix=40, numMin=10, LModeFilter=True, cbarMin=0.75, cbarMax=3.75,countType="pedestalHeight")

# %%
b = np.array([1.5, 2., 3.])

# %%
c = b.astype(int)

# %%
c

# %%
a.contourPlot(3, numMin=10, LModeFilter=True, countType="elong",cbarMin=1.95, cbarMax=2.1)

# %%
b.contourPlot(0)

# %%
a = Shot(45270, "all")

# %%
a.fit()

# %%
from Shot import *

# %%
a = Shot()

# %%
from Shot import *
a = Shot("allShots", "pkl")
for i in range(1):
    a.contourPlot(2, lowSlopeFilter=True,numPix=40,IpMin=0.9, numMin=10, cbarMin=1.95,cbarMax=2.1, countType="elong")

# %%
from Shot import *
a = Shot("allShots", "pkl")
for i in range(1):
    a.contourPlot(3, lowSlopeFilter=True,numPix=50,IpMin=0.9, numMin=10, cbarMin=1.95,cbarMax=2.1, countType="elong")

# %%
a.contourPlot(10, lowSlopeFilter=True, IpMin=0.9, numMin=10, numPix=50, cbarMin=1,cbarMax=2.5)

# %%
a.contourPlot(1, lowSlopeFilter=True,numPix=45,IpMin=0.9, numMin=10, cbarMin=1,cbarMax=1.8)

   
a.contourPlot(1, lowSlopeFilter=True,numPix=45,IpMin=0.9, numMin=10, cbarMin=0.4,cbarMax=0.6, countType="delta")

# %%
a.contourPlot(1, lowSlopeFilter=True,numPix=45,IpMin=0.9, numMin=10, cbarMin=1.95,cbarMax=2.1, countType="elong")

# %%
   a.contourPlot(2, lowSlopeFilter=True,numPix=50,IpMin=0.9, numMin=10, cbarMin=0.45,cbarMax=0.55, countType="delta")

   a.contourPlot(3, lowSlopeFilter=True,numPix=50,IpMin=0.9, numMin=10, cbarMin=0.45,cbarMax=0.55, countType="delta")

# %%
from Shot import *
a = Shot("allShots", "pkl")

# %%
a.contourPlot(11, cbarMin=.45, cbarMax=.55, countType="delta", numMin=10)

# %%
a.contourPlot(11, cbarMin=1.95, cbarMax=2.1, countType="elong", numMin=10)

# %%
a.contourPlot(11, cbarMin=1)

# %%
a.contourPlot(2, lowSlopeFilter=True,numPix=50,IpMin=0.9, numMin=10, cbarMin=0.45,cbarMax=0.55, countType="delta")

a.contourPlot(3, lowSlopeFilter=True,numPix=50,IpMin=0.9, numMin=10, cbarMin=0.45,cbarMax=0.55, countType="delta")

# %%
a.contourPlot(1, lowSlopeFilter=True,numPix=45,IpMin=0.9, numMin=10, cbarMin=0.45,cbarMax=0.55, countType="delta")

# %%
UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
a = Shot("allShots", "pkl")
fig, ax = plt.subplots(1, 1) 
ax.hist(a.NBI, bins = 200, range=(0,5)) 
  
# Set title 
ax.set_title("NBI Power") 
  
# adding labels 
ax.set_xlabel('NBIPower') 
ax.set_ylabel('counts') 
plt.savefig("plots/NBIPowerHistogram")
plt.show()
# Out:
# Downloading pkl data...
# Pkl data loaded

# %%
#a = Shot("allShots", "pkl", folder = "outputWithPlasmaCurrent")
# Out:
# Downloading pkl data...
# Pkl data loaded
# 37919

# %%
a.contourPlot(1, cbarMin=0, cbarMax=1.75,lowSlopeFilter=0, numMin=0, IpMin=0, plotName="2guns")
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[8], line 1
#
# ----> 1 a.contourPlot(1, cbarMin=0, cbarMax=1.75,lowSlopeFilter=0, numMin=0, IpMin=0, plotName="2guns")
#
#
#
# File ~/Documents/hardDrive/pppl/pedestal/pedestal.py:1282, in Shot.contourPlot(self, plotnumber, saveFigure, showFigure, fitHMode, plotName, numPix, cbarMax, cbarMin, numMin, countType, IpMin, lowSlopeFilter)
#
#    1277 outfilename = str(self.shotNum) + outfilename + "Colored" + countType
#
#    1278 args = [plotnumber,outfilename,
#
#    1279         xquantity,xlabel,x1,x2,xticks,xminor,xsize,
#
#    1280         yquantity,ylabel,y1,y2,yticks,yminor,ysize, self]
#
# -> 1282 makefigure(*args)
#
#
#
# File ~/Documents/hardDrive/pppl/pedestal/pedestal.py:850, in Shot.contourPlot.<locals>.makefigure(*args)
#
#     841 for i in range(0,len(xx)-1):
#
#     842     for j in range(0,len(yy)-1):
#
#     843         #Can add additional conditions here to filter what is shown in contour
#
#     844         index, = np.where((xquantity>=xx[i])   &
#
#     845                             (xquantity< xx[i+1]) &
#
#     846                             (yquantity>=yy[j])   &
#
#     847                             (yquantity< yy[j+1]) &
#
#     848                             (self.Ip>IpMin*self.IpMax) &
#
#     849                             (self.Beta_ped/self.W_ped >lowSlopeFilter) &
#
# --> 850                             (self.NBI>2.2))
#
#     852         if len(index) >= numMin:
#
#     853             totalPoints += len(index)
#
#
#
# TypeError: '>' not supported between instances of 'list' and 'float'

# %%
plt.scatter(y=a.W_ped, x=a.Beta_ped, c=a.NBI, cmap="rainbow", s= 0.6, alpha=0.6) 
# plt.xlim(1,3)
plt.ylabel(r"$\delta$")
plt.xlabel(r"$\kappa$")
plt.ylim(0, 0.3)
plt.xlim(0, 0.15)
# plt.ylim(0,1)
plt.colorbar(label="Fraction of Max Plasma Current", orientation="horizontal") 
plt.savefig("allShotsElongVsDeltaIpColored.png")
plt.show()

# %%
# pickleCombine()
a = Shot("48177", "pkl")
a.shotIndexed
# Out:
# Downloading pkl data...
# Pkl data loaded
# False

# %%
numpy.full(10, 5>6)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False])

# %%
a = Shot("48177", "pkl")
plt.plot(a.times, a.NBI, label="total")
plt.plot(a.times, a.ssNBI, label = "South")
plt.plot(a.times, a.swNBI, label = "Southwest")
plt.xlabel("time (s)")
plt.ylabel("NBI power (MW)")
plt.title("48177 NBI Power vs Time")
plt.legend()
# Out:
# Downloading pkl data...
# Pkl data loaded

# %%
a = Shot("48221", "pkl")
plt.plot(a.times, a.NBI)
plt.plot(a.times, a.ssNBI)
plt.plot(a.times, a.swNBI)

plt.xlabel("time (s)")
plt.ylabel("NBI power (MW)")
# Out:
# Downloading pkl data...
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_48221.pkl'
# Pkl data procurement failed
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[7], line 2
#
#       1 a = Shot("48221", "pkl")
#
# ----> 2 plt.plot(a.times, a.NBI)
#
#       3 plt.plot(a.times, a.ssNBI)
#
#       4 plt.plot(a.times, a.swNBI)
#
#
#
# AttributeError: 'Shot' object has no attribute 'times'

# %%
plt.plot(a.NBI)

# %%
30*5280/3600
# Out:
# 44.0

# %%
605/11
# Out:
# 55.0

# %%
b=Shot("allShots", "pkl", folder = "outputWithBeamPower3")
# Out:
# Downloading pkl data...
# Pkl data loaded

# %%
len(b.shot)
# Out:
# 390

# %%
c = Shot("allShots", "pkl", folder = "outputWithBeamPower2")
# Out:
# Downloading pkl data...
# 'Ip'
# Pkl data procurement failed

# %%
len(c.shot)
# Out:
# 712

# %%
from pedestal import *
# Out:
# Importing libraries...
# pedinf connection failed
# pyuda connection failed
# Libraries imported.

# %%
pickleCombine()

# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv("MU03_shotlist_v2_beams.csv", header = None)
df
# Out:
#          0               1
# 0    47608  .DN-0750-CD-SW
# 1    47659  .DN-0750-CD-SW
# 2    47665  .DN-0750-CD-SW
# 3    47702  .DN-0750-CD-SW
# 4    47710  .DN-0750-CD-SW
# ..     ...             ...
# 773  49464  .DN-0600-CD-2B
# 774  49465  .DN-0600-SF-2B
# 775  49466  .DN-0600-SF-2B
# 776  49467  .DN-0600-SF-2B
# 777  49468  .DN-0600-SF-2B
#
# [778 rows x 2 columns]

# %%
nullCodes = np.empty(len(df[1]), dtype='<U2')
beamPowerCodes = np.empty(len(df[1]), dtype='<U4')
divertorCodes = np.empty(len(df[1]), dtype='<U2')
beamCodes = np.empty(len(df[1]),dtype='<U2')

# %%
for i in range(len(df[1])):
    nullCode = df[1][i][-13:-11]
    nullCodes[i]=nullCode   
    beamPowerCode = df[1][i][-10:-6]
    beamPowerCodes[i]=beamPowerCode
    divertorCode = df[1][i][-5:-3]
    divertorCodes[i]=divertorCode
    beamCode = df[1][i][-2:]
    beamCodes[i]=beamCode

# %%
df[2] = nullCodes
df[3]=beamPowerCodes
df[4] = divertorCodes
df[5]=beamCodes

# %%
df
# Out:
#          0               1   2     3   4   5
# 0    47608  .DN-0750-CD-SW  DN  0750  CD  SW
# 1    47659  .DN-0750-CD-SW  DN  0750  CD  SW
# 2    47665  .DN-0750-CD-SW  DN  0750  CD  SW
# 3    47702  .DN-0750-CD-SW  DN  0750  CD  SW
# 4    47710  .DN-0750-CD-SW  DN  0750  CD  SW
# ..     ...             ...  ..   ...  ..  ..
# 773  49464  .DN-0600-CD-2B  DN  0600  CD  2B
# 774  49465  .DN-0600-SF-2B  DN  0600  SF  2B
# 775  49466  .DN-0600-SF-2B  DN  0600  SF  2B
# 776  49467  .DN-0600-SF-2B  DN  0600  SF  2B
# 777  49468  .DN-0600-SF-2B  DN  0600  SF  2B
#
# [778 rows x 6 columns]

# %%
df.rename(columns={0:"Shot", 1:"Tag", 2:"Nullity", 3:"Beam Power", 4:"Divertor", 5:"Beam Number"})
# Out:
#       Shot             Tag Nullity Beam Power Divertor Beam Number
# 0    47608  .DN-0750-CD-SW      DN       0750       CD          SW
# 1    47659  .DN-0750-CD-SW      DN       0750       CD          SW
# 2    47665  .DN-0750-CD-SW      DN       0750       CD          SW
# 3    47702  .DN-0750-CD-SW      DN       0750       CD          SW
# 4    47710  .DN-0750-CD-SW      DN       0750       CD          SW
# ..     ...             ...     ...        ...      ...         ...
# 773  49464  .DN-0600-CD-2B      DN       0600       CD          2B
# 774  49465  .DN-0600-SF-2B      DN       0600       SF          2B
# 775  49466  .DN-0600-SF-2B      DN       0600       SF          2B
# 776  49467  .DN-0600-SF-2B      DN       0600       SF          2B
# 777  49468  .DN-0600-SF-2B      DN       0600       SF          2B
#
# [778 rows x 6 columns]

# %%
df[df[0] == 47886][0]
# Out:
# 24    47886
# Name: 0, dtype: int64

# %%
np.array(df.loc[df[0] == 47888][2])[0]
# Out:
# 'DN'

# %%
from pedestal import *
allShotNums = [47886, 47888, 47889, 47890, 47891, 47893, 47894, 47918, 47955, 47956, 47958, 47959, 47961, 47962, 47963, 47964, 47979, 47980, 47982, 47985, 47989, 47990, 47991, 47996, 47997, 47998, 47999, 48000, 48002, 48003, 48004, 48005, 48006, 48008, 48009, 48010, 48012, 48057, 48058, 48060, 48061, 48062, 48064, 48065, 48066, 48068, 48069, 48070, 48071, 48072, 48073, 48074, 48079, 48080, 48081, 48082, 48083, 48087, 48088, 48089, 48093, 48094, 48103, 48104, 48107, 48108, 48109, 48110, 48111, 48112, 48113, 48114, 48115, 48116, 48117, 48118, 48119, 48120, 48121, 48122, 48123, 48124, 48125, 48126, 48127, 48129, 48130, 48131, 48132, 48133, 48134, 48135, 48136, 48137, 48151, 48155, 48156, 48157, 48158, 48159, 48160, 48164, 48168, 48172, 48173, 48174, 48175, 48176, 48177, 48178, 48180, 48181, 48183, 48186, 48187, 48188, 48189, 48193, 48194, 48196, 48198, 48200, 48219, 48221, 48223, 48233, 48235, 48251, 48252, 48255, 48256, 48257, 48258, 48259, 48260, 48261, 48263, 48265, 48267, 48268, 48269, 48270, 48271, 48272, 48273, 48275, 48276, 48278, 48279, 48280, 48281, 48284, 48285, 48286, 48287, 48288, 48291, 48292, 48293, 48295, 48297, 48298, 48299, 48302, 48303, 48304, 48305, 48309, 48310, 48311, 48312, 48313, 48314, 48315, 48316, 48326, 48330, 48332, 48333, 48334, 48336, 48337, 48338, 48339, 48340, 48341, 48342, 48343, 48344, 48345, 48347, 48348, 48353, 48354, 48359, 48361, 48363, 48366, 48367, 48368, 48369, 48370, 48558, 48559, 48560, 48561, 48579, 48580, 48594, 48595, 48596, 48597, 48598, 48599, 48602, 48603, 48604, 48605, 48606, 48609, 48611, 48614, 48615, 48616, 48617, 48618, 48619, 48620, 48622, 48623, 48630, 48631, 48632, 48634, 48636, 48638, 48639, 48640, 48641, 48642, 48643, 48646, 48647, 48648, 48649, 48651, 48652, 48653, 48654, 48655, 48656, 48657, 48658, 48666, 48668, 48669, 48670, 48671, 48672, 48710, 48711, 48712, 48714, 48715,
380, 49383, 49384, 49385, 49386, 49387, 49388, 49389, 49390, 49391, 49392, 49394, 49395, 49396, 49397, 49398, 49399, 49400, 49401, 49404, 49405, 49407, 49408, 49409, 49410, 49411, 49412, 49413, 49414, 49415, 49416, 49417, 49418, 49419, 49420, 49421, 49422, 49423, 49425, 49426, 49427, 49428, 49429, 49430, 49431, 49432, 49433, 49434, 49435, 49436, 49437, 49438, 49439, 49442, 49444, 49445, 49447, 49449, 49450, 49451, 49452, 49453, 49454, 49456, 49457, 49458, 49459, 49460, 49461, 49462, 49463, 49464, 49465, 49466, 49467, 49468]
print(len(allShotNums))
failedShotNums = []
for i in allShotNums:
    try:
        a = Shot(i, "pkl")
        nullCodes = np.empty(len(a.times), dtype='<U2')
        beamPowerCodes = np.empty(len(a.times), dtype='<U4')
        divertorCodes = np.empty(len(a.times), dtype='<U2')
        beamCodes = np.empty(len(a.times),dtype='<U2')
        for j in range(len(a.times)):
            nullCode = np.array(df[df[0] == i][2])[0]
            nullCodes[j]=nullCode   
            beamPowerCode = np.array(df[df[0] == i][3])[0]
            beamPowerCodes[j]=beamPowerCode
            divertorCode = np.array(df[df[0] == i][4])[0]
            divertorCodes[j]=divertorCode
            beamCode = np.array(df[df[0] == i][5])[0]
            beamCodes[j]=beamCode
        pkldata = {'shot': a.shot, 'times': a.times, 'W_ped': a.W_ped, 'Beta_ped': a.Beta_ped,
                    'W_ped_psin_te': a.W_ped_psin_te,'W_ped_psin_ne': a.W_ped_psin_ne,'W_ped_psin_pe': a.W_ped_psin_pe,
                    'H_ped_psin_te': a.H_ped_psin_te,'H_ped_psin_ne': a.H_ped_psin_ne,'H_ped_psin_pe': a.H_ped_psin_pe,
                    'W_ped_radius_te': a.W_ped_radius_te,'W_ped_radius_ne': a.W_ped_radius_ne,'W_ped_radius_pe': a.W_ped_radius_pe,
                    'H_ped_radius_te': a.H_ped_radius_te,'H_ped_radius_ne': a.H_ped_radius_ne,'H_ped_radius_pe': a.H_ped_radius_pe,
                    'aratio': a.aratio, 'elong': a.elong, 'delta': a.delta, 'NBI': a.NBI, 'ssNBI':a.ssNBI, "swNBI":a.swNBI,
                    "IpMax":a.IpMax, "Ip":a.Ip, "shotIndexed":a.shotIndexed, "betaN":a.betaN, "nullity":nullCodes, "beamPower":beamPowerCodes, "divertor":divertorCodes, "whichBeams":beamCodes}
        filename = 'outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_'+str(i)+'.pkl'
        outfile = open(filename, 'wb')
        pickle.dump(pkldata,outfile)
        outfile.close()
        print('outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_'+str(i)+'.pkl saved')


    except Exception as error:
        print(error)
        failedShotNums += [i]

print(failedShotNums)
print(len(failedShotNums))
# Out:
# 726
# Downloading pkl data... 47886
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47886.pkl saved
# Downloading pkl data... 47888
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47888.pkl saved
# Downloading pkl data... 47889
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47889.pkl saved
# Downloading pkl data... 47890
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47890.pkl saved
# Downloading pkl data... 47891
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47891.pkl saved
# Downloading pkl data... 47893
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47893.pkl saved
# Downloading pkl data... 47894
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47894.pkl saved
# Downloading pkl data... 47918
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47918.pkl saved
# Downloading pkl data... 47955
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47955.pkl saved
# Downloading pkl data... 47956
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_47956.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 47958
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47958.pkl saved
# Downloading pkl data... 47959
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47959.pkl saved
# Downloading pkl data... 47961
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47961.pkl saved
# Downloading pkl data... 47962
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47962.pkl saved
# Downloading pkl data... 47963
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47963.pkl saved
# Downloading pkl data... 47964
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47964.pkl saved
# Downloading pkl data... 47979
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47979.pkl saved
# Downloading pkl data... 47980
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47980.pkl saved
# Downloading pkl data... 47982
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_47982.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 47985
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47985.pkl saved
# Downloading pkl data... 47989
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47989.pkl saved
# Downloading pkl data... 47990
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47990.pkl saved
# Downloading pkl data... 47991
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47991.pkl saved
# Downloading pkl data... 47996
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47996.pkl saved
# Downloading pkl data... 47997
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47997.pkl saved
# Downloading pkl data... 47998
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47998.pkl saved
# Downloading pkl data... 47999
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_47999.pkl saved
# Downloading pkl data... 48000
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48000.pkl saved
# Downloading pkl data... 48002
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48002.pkl saved
# Downloading pkl data... 48003
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48003.pkl saved
# Downloading pkl data... 48004
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48004.pkl saved
# Downloading pkl data... 48005
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48005.pkl saved
# Downloading pkl data... 48006
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48006.pkl saved
# Downloading pkl data... 48008
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48008.pkl saved
# Downloading pkl data... 48009
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48009.pkl saved
# Downloading pkl data... 48010
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48010.pkl saved
# Downloading pkl data... 48012
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48012.pkl saved
# Downloading pkl data... 48057
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48057.pkl saved
# Downloading pkl data... 48058
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48058.pkl saved
# Downloading pkl data... 48060
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48060.pkl saved
# Downloading pkl data... 48061
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48061.pkl saved
# Downloading pkl data... 48062
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48062.pkl saved
# Downloading pkl data... 48064
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48064.pkl saved
# Downloading pkl data... 48065
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48065.pkl saved
# Downloading pkl data... 48066
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48066.pkl saved
# Downloading pkl data... 48068
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48068.pkl saved
# Downloading pkl data... 48069
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48069.pkl saved
# Downloading pkl data... 48070
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48070.pkl saved
# Downloading pkl data... 48071
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_48071.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 48072
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48072.pkl saved
# Downloading pkl data... 48073
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48073.pkl saved
# Downloading pkl data... 48074
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48074.pkl saved
# Downloading pkl data... 48079
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48079.pkl saved
# Downloading pkl data... 48080
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48080.pkl saved
# Downloading pkl data... 48081
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48081.pkl saved
# Downloading pkl data... 48082
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48082.pkl saved
# Downloading pkl data... 48083
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48083.pkl saved
# Downloading pkl data... 48087
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48087.pkl saved
# Downloading pkl data... 48088
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48088.pkl saved
# Downloading pkl data... 48089
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48089.pkl saved
# Downloading pkl data... 48093
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48093.pkl saved
# Downloading pkl data... 48094
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48094.pkl saved
# Downloading pkl data... 48103
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48103.pkl saved
# Downloading pkl data... 48104
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48104.pkl saved
# Downloading pkl data... 48107
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48107.pkl saved
# Downloading pkl data... 48108
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48108.pkl saved
# Downloading pkl data... 48109
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48109.pkl saved
# Downloading pkl data... 48110
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48110.pkl saved
# Downloading pkl data... 48111
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48111.pkl saved
# Downloading pkl data... 48112
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48112.pkl saved
# Downloading pkl data... 48113
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48113.pkl saved
# Downloading pkl data... 48114
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48114.pkl saved
# Downloading pkl data... 48115
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48115.pkl saved
# Downloading pkl data... 48116
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48116.pkl saved
# Downloading pkl data... 48117
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48117.pkl saved
# Downloading pkl data... 48118
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48118.pkl saved
# Downloading pkl data... 48119
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48119.pkl saved
# Downloading pkl data... 48120
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48120.pkl saved
# Downloading pkl data... 48121
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48121.pkl saved
# Downloading pkl data... 48122
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48122.pkl saved
# Downloading pkl data... 48123
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48123.pkl saved
# Downloading pkl data... 48124
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48124.pkl saved
# Downloading pkl data... 48125
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48125.pkl saved
# Downloading pkl data... 48126
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48126.pkl saved
# Downloading pkl data... 48127
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48127.pkl saved
# Downloading pkl data... 48129
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48129.pkl saved
# Downloading pkl data... 48130
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48130.pkl saved
# Downloading pkl data... 48131
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48131.pkl saved
# Downloading pkl data... 48132
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48132.pkl saved
# Downloading pkl data... 48133
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48133.pkl saved
# Downloading pkl data... 48134
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48134.pkl saved
# Downloading pkl data... 48135
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48135.pkl saved
# Downloading pkl data... 48136
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48136.pkl saved
# Downloading pkl data... 48137
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48137.pkl saved
# Downloading pkl data... 48151
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48151.pkl saved
# Downloading pkl data... 48155
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48155.pkl saved
# Downloading pkl data... 48156
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_48156.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 48157
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48157.pkl saved
# Downloading pkl data... 48158
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48158.pkl saved
# Downloading pkl data... 48159
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48159.pkl saved
# Downloading pkl data... 48160
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48160.pkl saved
# Downloading pkl data... 48164
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48164.pkl saved
# Downloading pkl data... 48168
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48168.pkl saved
# Downloading pkl data... 48172
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48172.pkl saved
# Downloading pkl data... 48173
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48173.pkl saved
# Downloading pkl data... 48174
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48174.pkl saved
# Downloading pkl data... 48175
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48175.pkl saved
# Downloading pkl data... 48176
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48176.pkl saved
# Downloading pkl data... 48177
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48177.pkl saved
# Downloading pkl data... 48178
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48178.pkl saved
# Downloading pkl data... 48180
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48180.pkl saved
# Downloading pkl data... 48181
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48181.pkl saved
# Downloading pkl data... 48183
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48183.pkl saved
# Downloading pkl data... 48186
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48186.pkl saved
# Downloading pkl data... 48187
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48187.pkl saved
# Downloading pkl data... 48188
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48188.pkl saved
# Downloading pkl data... 48189
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48189.pkl saved
# Downloading pkl data... 48193
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48193.pkl saved
# Downloading pkl data... 48194
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48194.pkl saved
# Downloading pkl data... 48196
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48196.pkl saved
# Downloading pkl data... 48198
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48198.pkl saved
# Downloading pkl data... 48200
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48200.pkl saved
# Downloading pkl data... 48219
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48219.pkl saved
# Downloading pkl data... 48221
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48221.pkl saved
# Downloading pkl data... 48223
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48223.pkl saved
# Downloading pkl data... 48233
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48233.pkl saved
# Downloading pkl data... 48235
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48235.pkl saved
# Downloading pkl data... 48251
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48251.pkl saved
# Downloading pkl data... 48252
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48252.pkl saved
# Downloading pkl data... 48255
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48255.pkl saved
# Downloading pkl data... 48256
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48256.pkl saved
# Downloading pkl data... 48257
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48257.pkl saved
# Downloading pkl data... 48258
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48258.pkl saved
# Downloading pkl data... 48259
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48259.pkl saved
# Downloading pkl data... 48260
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48260.pkl saved
# Downloading pkl data... 48261
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48261.pkl saved
# Downloading pkl data... 48263
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48263.pkl saved
# Downloading pkl data... 48265
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48265.pkl saved
# Downloading pkl data... 48267
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48267.pkl saved
# Downloading pkl data... 48268
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48268.pkl saved
# Downloading pkl data... 48269
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48269.pkl saved
# Downloading pkl data... 48270
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48270.pkl saved
# Downloading pkl data... 48271
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48271.pkl saved
# Downloading pkl data... 48272
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48272.pkl saved
# Downloading pkl data... 48273
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48273.pkl saved
# Downloading pkl data... 48275
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48275.pkl saved
# Downloading pkl data... 48276
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48276.pkl saved
# Downloading pkl data... 48278
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48278.pkl saved
# Downloading pkl data... 48279
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48279.pkl saved
# Downloading pkl data... 48280
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48280.pkl saved
# Downloading pkl data... 48281
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48281.pkl saved
# Downloading pkl data... 48284
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48284.pkl saved
# Downloading pkl data... 48285
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48285.pkl saved
# Downloading pkl data... 48286
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48286.pkl saved
# Downloading pkl data... 48287
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48287.pkl saved
# Downloading pkl data... 48288
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48288.pkl saved
# Downloading pkl data... 48291
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_48291.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 48292
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48292.pkl saved
# Downloading pkl data... 48293
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48293.pkl saved
# Downloading pkl data... 48295
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48295.pkl saved
# Downloading pkl data... 48297
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48297.pkl saved
# Downloading pkl data... 48298
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48298.pkl saved
# Downloading pkl data... 48299
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48299.pkl saved
# Downloading pkl data... 48302
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48302.pkl saved
# Downloading pkl data... 48303
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48303.pkl saved
# Downloading pkl data... 48304
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48304.pkl saved
# Downloading pkl data... 48305
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48305.pkl saved
# Downloading pkl data... 48309
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48309.pkl saved
# Downloading pkl data... 48310
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48310.pkl saved
# Downloading pkl data... 48311
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48311.pkl saved
# Downloading pkl data... 48312
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48312.pkl saved
# Downloading pkl data... 48313
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48313.pkl saved
# Downloading pkl data... 48314
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48314.pkl saved
# Downloading pkl data... 48315
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48315.pkl saved
# Downloading pkl data... 48316
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48316.pkl saved
# Downloading pkl data... 48326
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48326.pkl saved
# Downloading pkl data... 48330
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48330.pkl saved
# Downloading pkl data... 48332
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48332.pkl saved
# Downloading pkl data... 48333
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48333.pkl saved
# Downloading pkl data... 48334
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48334.pkl saved
# Downloading pkl data... 48336
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48336.pkl saved
# Downloading pkl data... 48337
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48337.pkl saved
# Downloading pkl data... 48338
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48338.pkl saved
# Downloading pkl data... 48339
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48339.pkl saved
# Downloading pkl data... 48340
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48340.pkl saved
# Downloading pkl data... 48341
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48341.pkl saved
# Downloading pkl data... 48342
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48342.pkl saved
# Downloading pkl data... 48343
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48343.pkl saved
# Downloading pkl data... 48344
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48344.pkl saved
# Downloading pkl data... 48345
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48345.pkl saved
# Downloading pkl data... 48347
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48347.pkl saved
# Downloading pkl data... 48348
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48348.pkl saved
# Downloading pkl data... 48353
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48353.pkl saved
# Downloading pkl data... 48354
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48354.pkl saved
# Downloading pkl data... 48359
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48359.pkl saved
# Downloading pkl data... 48361
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48361.pkl saved
# Downloading pkl data... 48363
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48363.pkl saved
# Downloading pkl data... 48366
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48366.pkl saved
# Downloading pkl data... 48367
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48367.pkl saved
# Downloading pkl data... 48368
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48368.pkl saved
# Downloading pkl data... 48369
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48369.pkl saved
# Downloading pkl data... 48370
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48370.pkl saved
# Downloading pkl data... 48558
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48558.pkl saved
# Downloading pkl data... 48559
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48559.pkl saved
# Downloading pkl data... 48560
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48560.pkl saved
# Downloading pkl data... 48561
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48561.pkl saved
# Downloading pkl data... 48579
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48579.pkl saved
# Downloading pkl data... 48580
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48580.pkl saved
# Downloading pkl data... 48594
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48594.pkl saved
# Downloading pkl data... 48595
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48595.pkl saved
# Downloading pkl data... 48596
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48596.pkl saved
# Downloading pkl data... 48597
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48597.pkl saved
# Downloading pkl data... 48598
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48598.pkl saved
# Downloading pkl data... 48599
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48599.pkl saved
# Downloading pkl data... 48602
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48602.pkl saved
# Downloading pkl data... 48603
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48603.pkl saved
# Downloading pkl data... 48604
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48604.pkl saved
# Downloading pkl data... 48605
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48605.pkl saved
# Downloading pkl data... 48606
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48606.pkl saved
# Downloading pkl data... 48609
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48609.pkl saved
# Downloading pkl data... 48611
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48611.pkl saved
# Downloading pkl data... 48614
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48614.pkl saved
# Downloading pkl data... 48615
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48615.pkl saved
# Downloading pkl data... 48616
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48616.pkl saved
# Downloading pkl data... 48617
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48617.pkl saved
# Downloading pkl data... 48618
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48618.pkl saved
# Downloading pkl data... 48619
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48619.pkl saved
# Downloading pkl data... 48620
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48620.pkl saved
# Downloading pkl data... 48622
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48622.pkl saved
# Downloading pkl data... 48623
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48623.pkl saved
# Downloading pkl data... 48630
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48630.pkl saved
# Downloading pkl data... 48631
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48631.pkl saved
# Downloading pkl data... 48632
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48632.pkl saved
# Downloading pkl data... 48634
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48634.pkl saved
# Downloading pkl data... 48636
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48636.pkl saved
# Downloading pkl data... 48638
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48638.pkl saved
# Downloading pkl data... 48639
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48639.pkl saved
# Downloading pkl data... 48640
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48640.pkl saved
# Downloading pkl data... 48641
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48641.pkl saved
# Downloading pkl data... 48642
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48642.pkl saved
# Downloading pkl data... 48643
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48643.pkl saved
# Downloading pkl data... 48646
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48646.pkl saved
# Downloading pkl data... 48647
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48647.pkl saved
# Downloading pkl data... 48648
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48648.pkl saved
# Downloading pkl data... 48649
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48649.pkl saved
# Downloading pkl data... 48651
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48651.pkl saved
# Downloading pkl data... 48652
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48652.pkl saved
# Downloading pkl data... 48653
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48653.pkl saved
# Downloading pkl data... 48654
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48654.pkl saved
# Downloading pkl data... 48655
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48655.pkl saved
# Downloading pkl data... 48656
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48656.pkl saved
# Downloading pkl data... 48657
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48657.pkl saved
# Downloading pkl data... 48658
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48658.pkl saved
# Downloading pkl data... 48666
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48666.pkl saved
# Downloading pkl data... 48668
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48668.pkl saved
# Downloading pkl data... 48669
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48669.pkl saved
# Downloading pkl data... 48670
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48670.pkl saved
# Downloading pkl data... 48671
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48671.pkl saved
# Downloading pkl data... 48672
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48672.pkl saved
# Downloading pkl data... 48710
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48710.pkl saved
# Downloading pkl data... 48711
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48711.pkl saved
# Downloading pkl data... 48712
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48712.pkl saved
# Downloading pkl data... 48714
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48714.pkl saved
# Downloading pkl data... 48715
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48715.pkl saved
# Downloading pkl data... 48716
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48716.pkl saved
# Downloading pkl data... 48717
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48717.pkl saved
# Downloading pkl data... 48718
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48718.pkl saved
# Downloading pkl data... 48721
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48721.pkl saved
# Downloading pkl data... 48722
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48722.pkl saved
# Downloading pkl data... 48723
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48723.pkl saved
# Downloading pkl data... 48725
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48725.pkl saved
# Downloading pkl data... 48726
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48726.pkl saved
# Downloading pkl data... 48735
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48735.pkl saved
# Downloading pkl data... 48738
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48738.pkl saved
# Downloading pkl data... 48740
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48740.pkl saved
# Downloading pkl data... 48743
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48743.pkl saved
# Downloading pkl data... 48745
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48745.pkl saved
# Downloading pkl data... 48749
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48749.pkl saved
# Downloading pkl data... 48750
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48750.pkl saved
# Downloading pkl data... 48752
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48752.pkl saved
# Downloading pkl data... 48755
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48755.pkl saved
# Downloading pkl data... 48758
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48758.pkl saved
# Downloading pkl data... 48759
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48759.pkl saved
# Downloading pkl data... 48760
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48760.pkl saved
# Downloading pkl data... 48761
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48761.pkl saved
# Downloading pkl data... 48762
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48762.pkl saved
# Downloading pkl data... 48763
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48763.pkl saved
# Downloading pkl data... 48764
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48764.pkl saved
# Downloading pkl data... 48765
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48765.pkl saved
# Downloading pkl data... 48766
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48766.pkl saved
# Downloading pkl data... 48767
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48767.pkl saved
# Downloading pkl data... 48768
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48768.pkl saved
# Downloading pkl data... 48769
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48769.pkl saved
# Downloading pkl data... 48772
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48772.pkl saved
# Downloading pkl data... 48777
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48777.pkl saved
# Downloading pkl data... 48778
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48778.pkl saved
# Downloading pkl data... 48779
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48779.pkl saved
# Downloading pkl data... 48780
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48780.pkl saved
# Downloading pkl data... 48788
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48788.pkl saved
# Downloading pkl data... 48789
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48789.pkl saved
# Downloading pkl data... 48791
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48791.pkl saved
# Downloading pkl data... 48797
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48797.pkl saved
# Downloading pkl data... 48798
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48798.pkl saved
# Downloading pkl data... 48799
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48799.pkl saved
# Downloading pkl data... 48800
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48800.pkl saved
# Downloading pkl data... 48801
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48801.pkl saved
# Downloading pkl data... 48802
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48802.pkl saved
# Downloading pkl data... 48803
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48803.pkl saved
# Downloading pkl data... 48804
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48804.pkl saved
# Downloading pkl data... 48805
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48805.pkl saved
# Downloading pkl data... 48806
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48806.pkl saved
# Downloading pkl data... 48807
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48807.pkl saved
# Downloading pkl data... 48808
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48808.pkl saved
# Downloading pkl data... 48809
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48809.pkl saved
# Downloading pkl data... 48811
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48811.pkl saved
# Downloading pkl data... 48812
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48812.pkl saved
# Downloading pkl data... 48813
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48813.pkl saved
# Downloading pkl data... 48816
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48816.pkl saved
# Downloading pkl data... 48817
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48817.pkl saved
# Downloading pkl data... 48818
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48818.pkl saved
# Downloading pkl data... 48819
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48819.pkl saved
# Downloading pkl data... 48820
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48820.pkl saved
# Downloading pkl data... 48821
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48821.pkl saved
# Downloading pkl data... 48822
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48822.pkl saved
# Downloading pkl data... 48823
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48823.pkl saved
# Downloading pkl data... 48824
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48824.pkl saved
# Downloading pkl data... 48825
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48825.pkl saved
# Downloading pkl data... 48826
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48826.pkl saved
# Downloading pkl data... 48827
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48827.pkl saved
# Downloading pkl data... 48828
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48828.pkl saved
# Downloading pkl data... 48829
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48829.pkl saved
# Downloading pkl data... 48830
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48830.pkl saved
# Downloading pkl data... 48832
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48832.pkl saved
# Downloading pkl data... 48834
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48834.pkl saved
# Downloading pkl data... 48835
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48835.pkl saved
# Downloading pkl data... 48836
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48836.pkl saved
# Downloading pkl data... 48840
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48840.pkl saved
# Downloading pkl data... 48841
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48841.pkl saved
# Downloading pkl data... 48842
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48842.pkl saved
# Downloading pkl data... 48844
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48844.pkl saved
# Downloading pkl data... 48845
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48845.pkl saved
# Downloading pkl data... 48846
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48846.pkl saved
# Downloading pkl data... 48847
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48847.pkl saved
# Downloading pkl data... 48849
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48849.pkl saved
# Downloading pkl data... 48850
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48850.pkl saved
# Downloading pkl data... 48851
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48851.pkl saved
# Downloading pkl data... 48853
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48853.pkl saved
# Downloading pkl data... 48863
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48863.pkl saved
# Downloading pkl data... 48864
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48864.pkl saved
# Downloading pkl data... 48866
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48866.pkl saved
# Downloading pkl data... 48867
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48867.pkl saved
# Downloading pkl data... 48868
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48868.pkl saved
# Downloading pkl data... 48869
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48869.pkl saved
# Downloading pkl data... 48870
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48870.pkl saved
# Downloading pkl data... 48871
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48871.pkl saved
# Downloading pkl data... 48872
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48872.pkl saved
# Downloading pkl data... 48873
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48873.pkl saved
# Downloading pkl data... 48874
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48874.pkl saved
# Downloading pkl data... 48879
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48879.pkl saved
# Downloading pkl data... 48880
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48880.pkl saved
# Downloading pkl data... 48882
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48882.pkl saved
# Downloading pkl data... 48883
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48883.pkl saved
# Downloading pkl data... 48884
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48884.pkl saved
# Downloading pkl data... 48885
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48885.pkl saved
# Downloading pkl data... 48886
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48886.pkl saved
# Downloading pkl data... 48888
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48888.pkl saved
# Downloading pkl data... 48889
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48889.pkl saved
# Downloading pkl data... 48890
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48890.pkl saved
# Downloading pkl data... 48892
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48892.pkl saved
# Downloading pkl data... 48893
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48893.pkl saved
# Downloading pkl data... 48894
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48894.pkl saved
# Downloading pkl data... 48895
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48895.pkl saved
# Downloading pkl data... 48896
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48896.pkl saved
# Downloading pkl data... 48898
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48898.pkl saved
# Downloading pkl data... 48899
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48899.pkl saved
# Downloading pkl data... 48900
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48900.pkl saved
# Downloading pkl data... 48901
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48901.pkl saved
# Downloading pkl data... 48902
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48902.pkl saved
# Downloading pkl data... 48903
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48903.pkl saved
# Downloading pkl data... 48904
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48904.pkl saved
# Downloading pkl data... 48906
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48906.pkl saved
# Downloading pkl data... 48907
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48907.pkl saved
# Downloading pkl data... 48908
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48908.pkl saved
# Downloading pkl data... 48909
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48909.pkl saved
# Downloading pkl data... 48910
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48910.pkl saved
# Downloading pkl data... 48911
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48911.pkl saved
# Downloading pkl data... 48912
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48912.pkl saved
# Downloading pkl data... 48913
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48913.pkl saved
# Downloading pkl data... 48915
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48915.pkl saved
# Downloading pkl data... 48916
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48916.pkl saved
# Downloading pkl data... 48917
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48917.pkl saved
# Downloading pkl data... 48918
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48918.pkl saved
# Downloading pkl data... 48919
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48919.pkl saved
# Downloading pkl data... 48920
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48920.pkl saved
# Downloading pkl data... 48921
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48921.pkl saved
# Downloading pkl data... 48925
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48925.pkl saved
# Downloading pkl data... 48926
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48926.pkl saved
# Downloading pkl data... 48927
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48927.pkl saved
# Downloading pkl data... 48928
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48928.pkl saved
# Downloading pkl data... 48929
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_48929.pkl saved
# Downloading pkl data... 48930
# Pkl data loaded
#
#
# ...
# Downloading pkl data... 49303
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49303.pkl saved
# Downloading pkl data... 49304
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49304.pkl saved
# Downloading pkl data... 49310
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49310.pkl saved
# Downloading pkl data... 49312
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49312.pkl saved
# Downloading pkl data... 49313
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49313.pkl saved
# Downloading pkl data... 49314
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49314.pkl saved
# Downloading pkl data... 49315
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49315.pkl saved
# Downloading pkl data... 49317
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49317.pkl saved
# Downloading pkl data... 49318
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49318.pkl saved
# Downloading pkl data... 49319
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49319.pkl saved
# Downloading pkl data... 49320
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49320.pkl saved
# Downloading pkl data... 49321
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49321.pkl saved
# Downloading pkl data... 49323
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49323.pkl saved
# Downloading pkl data... 49324
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49324.pkl saved
# Downloading pkl data... 49325
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49325.pkl saved
# Downloading pkl data... 49326
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49326.pkl saved
# Downloading pkl data... 49327
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49327.pkl saved
# Downloading pkl data... 49328
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49328.pkl saved
# Downloading pkl data... 49336
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49336.pkl saved
# Downloading pkl data... 49337
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49337.pkl saved
# Downloading pkl data... 49338
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49338.pkl saved
# Downloading pkl data... 49339
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49339.pkl saved
# Downloading pkl data... 49340
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49340.pkl saved
# Downloading pkl data... 49341
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49341.pkl saved
# Downloading pkl data... 49342
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49342.pkl saved
# Downloading pkl data... 49343
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49343.pkl saved
# Downloading pkl data... 49344
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49344.pkl saved
# Downloading pkl data... 49345
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49345.pkl saved
# Downloading pkl data... 49346
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49346.pkl saved
# Downloading pkl data... 49347
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49347.pkl saved
# Downloading pkl data... 49351
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_49351.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 49352
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_49352.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 49353
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_49353.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 49354
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49354.pkl saved
# Downloading pkl data... 49355
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49355.pkl saved
# Downloading pkl data... 49356
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49356.pkl saved
# Downloading pkl data... 49357
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49357.pkl saved
# Downloading pkl data... 49358
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49358.pkl saved
# Downloading pkl data... 49359
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49359.pkl saved
# Downloading pkl data... 49360
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49360.pkl saved
# Downloading pkl data... 49363
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49363.pkl saved
# Downloading pkl data... 49364
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49364.pkl saved
# Downloading pkl data... 49365
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49365.pkl saved
# Downloading pkl data... 49366
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49366.pkl saved
# Downloading pkl data... 49367
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49367.pkl saved
# Downloading pkl data... 49368
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49368.pkl saved
# Downloading pkl data... 49370
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49370.pkl saved
# Downloading pkl data... 49371
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49371.pkl saved
# Downloading pkl data... 49373
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49373.pkl saved
# Downloading pkl data... 49374
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49374.pkl saved
# Downloading pkl data... 49376
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49376.pkl saved
# Downloading pkl data... 49377
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49377.pkl saved
# Downloading pkl data... 49378
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49378.pkl saved
# Downloading pkl data... 49379
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_49379.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 49380
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49380.pkl saved
# Downloading pkl data... 49383
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49383.pkl saved
# Downloading pkl data... 49384
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49384.pkl saved
# Downloading pkl data... 49385
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49385.pkl saved
# Downloading pkl data... 49386
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49386.pkl saved
# Downloading pkl data... 49387
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49387.pkl saved
# Downloading pkl data... 49388
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49388.pkl saved
# Downloading pkl data... 49389
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49389.pkl saved
# Downloading pkl data... 49390
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49390.pkl saved
# Downloading pkl data... 49391
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49391.pkl saved
# Downloading pkl data... 49392
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49392.pkl saved
# Downloading pkl data... 49394
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49394.pkl saved
# Downloading pkl data... 49395
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49395.pkl saved
# Downloading pkl data... 49396
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49396.pkl saved
# Downloading pkl data... 49397
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49397.pkl saved
# Downloading pkl data... 49398
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49398.pkl saved
# Downloading pkl data... 49399
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49399.pkl saved
# Downloading pkl data... 49400
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49400.pkl saved
# Downloading pkl data... 49401
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49401.pkl saved
# Downloading pkl data... 49404
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49404.pkl saved
# Downloading pkl data... 49405
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49405.pkl saved
# Downloading pkl data... 49407
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49407.pkl saved
# Downloading pkl data... 49408
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49408.pkl saved
# Downloading pkl data... 49409
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49409.pkl saved
# Downloading pkl data... 49410
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49410.pkl saved
# Downloading pkl data... 49411
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49411.pkl saved
# Downloading pkl data... 49412
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49412.pkl saved
# Downloading pkl data... 49413
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_49413.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 49414
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49414.pkl saved
# Downloading pkl data... 49415
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49415.pkl saved
# Downloading pkl data... 49416
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49416.pkl saved
# Downloading pkl data... 49417
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49417.pkl saved
# Downloading pkl data... 49418
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49418.pkl saved
# Downloading pkl data... 49419
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49419.pkl saved
# Downloading pkl data... 49420
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49420.pkl saved
# Downloading pkl data... 49421
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49421.pkl saved
# Downloading pkl data... 49422
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49422.pkl saved
# Downloading pkl data... 49423
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49423.pkl saved
# Downloading pkl data... 49425
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49425.pkl saved
# Downloading pkl data... 49426
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49426.pkl saved
# Downloading pkl data... 49427
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49427.pkl saved
# Downloading pkl data... 49428
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49428.pkl saved
# Downloading pkl data... 49429
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49429.pkl saved
# Downloading pkl data... 49430
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49430.pkl saved
# Downloading pkl data... 49431
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49431.pkl saved
# Downloading pkl data... 49432
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49432.pkl saved
# Downloading pkl data... 49433
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49433.pkl saved
# Downloading pkl data... 49434
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49434.pkl saved
# Downloading pkl data... 49435
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49435.pkl saved
# Downloading pkl data... 49436
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49436.pkl saved
# Downloading pkl data... 49437
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49437.pkl saved
# Downloading pkl data... 49438
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49438.pkl saved
# Downloading pkl data... 49439
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49439.pkl saved
# Downloading pkl data... 49442
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49442.pkl saved
# Downloading pkl data... 49444
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49444.pkl saved
# Downloading pkl data... 49445
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49445.pkl saved
# Downloading pkl data... 49447
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49447.pkl saved
# Downloading pkl data... 49449
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49449.pkl saved
# Downloading pkl data... 49450
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49450.pkl saved
# Downloading pkl data... 49451
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49451.pkl saved
# Downloading pkl data... 49452
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49452.pkl saved
# Downloading pkl data... 49453
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49453.pkl saved
# Downloading pkl data... 49454
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49454.pkl saved
# Downloading pkl data... 49456
# [Errno 2] No such file or directory: 'outputWithBeamPower3/MAST-U_pedestal_49456.pkl'
# Pkl data procurement failed
#
#
# 'Shot' object has no attribute 'times'
# Downloading pkl data... 49457
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49457.pkl saved
# Downloading pkl data... 49458
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49458.pkl saved
# Downloading pkl data... 49459
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49459.pkl saved
# Downloading pkl data... 49460
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49460.pkl saved
# Downloading pkl data... 49461
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49461.pkl saved
# Downloading pkl data... 49462
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49462.pkl saved
# Downloading pkl data... 49463
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49463.pkl saved
# Downloading pkl data... 49464
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49464.pkl saved
# Downloading pkl data... 49465
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49465.pkl saved
# Downloading pkl data... 49466
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49466.pkl saved
# Downloading pkl data... 49467
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49467.pkl saved
# Downloading pkl data... 49468
# Pkl data loaded
#
#
# outputWithBeamPower3/outputWithTagData/MAST-U_pedestal_49468.pkl saved
# [47956, 47982, 48071, 48156, 48291, 49063, 49069, 49247, 49259, 49351, 49352, 49353, 49379, 49413, 49456]
# 15

# %%
from pedestal import *
# pickleCombine(folder="outputWithBeamPower3/outputWithTagData/")
# Out:
# Importing libraries...
# pedinf connection failed
# pyuda connection failed
# Libraries imported.

# %%
a = Shot("allShots", "pkl", folder="outputWithBeamPower3/outputWithTagData")
# Out:
# Downloading pkl data... allShots
# Pkl data loaded

# %%
a.whichBeams
# Out:
# array(['SW', 'SW', 'SW', ..., '2B', '2B', '2B'], dtype='<U2')

# %%
len(a.times)==len(a.whichBeams)
# Out:
# True

# %%
len(a.times)
# Out:
# 71331

# %%
a.contourPlot(1, numPix=300, numMin=0,cbarMin=1.9, cbarMax=2.1, countType="elong", lowSlopeFilter = 0)
# Out:
# /Users/evrydayorsted/Documents/hardDrive/pppl/pedestal/pedestal.py:853: RuntimeWarning: divide by zero encountered in divide
#   (self.Beta_ped/self.W_ped >lowSlopeFilter)&
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/evrydayorsted/Documents/hardDrive/pppl/pedestal/pedestal.py:997: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
